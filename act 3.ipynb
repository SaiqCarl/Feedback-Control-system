# %%
import control

# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [5,5]
den = [1, 4, 3]
G = ctrl.TransferFunction(num, den)
print(G)
# Out:
# <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#      5 s + 5
#   -------------
#   s^2 + 4 s + 3

# %%
poles = ctrl.poles(G)
print("Poles of the transfer function:", poles)
# Out:
# Poles of the transfer function: [-3.+0.j -1.+0.j]

# %%
zeros = ctrl.zeros(G)
print("Zeros of the transfer function:", zeros)
# Out:
# Zeros of the transfer function: [-1.+0.j]

# %%
ctrl.pzmap(G, grid=True)
plt.show()
