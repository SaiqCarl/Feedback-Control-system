# %%
# %pip install control
# Out:
# Requirement already satisfied: control in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.10.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from control) (2.3.5)
# Requirement already satisfied: scipy>=1.8 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from control) (1.17.1)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from control) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\carl joseph castillo\appdata\roaming\python\python314\site-packages (from matplotlib>=3.6->control) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\carl joseph castillo\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import control as ctrl
import matplotlib.pyplot as plt

num = [1]
den = [1, 2, 2]
G = ctrl.tf(num, den)
print(G)
# Out:
# <TransferFunction>: sys[3]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 2

# %%
poles = ctrl.poles(G)
print("Poles:", poles)
# Out:
# Poles: [-1.+1.j -1.-1.j]

# %%
zero=ctrl.zeros(G)
print("Zero:", zero)
# Out:
# Zero: []

# %%
import matplotlib.pyplot as plt
ctrl.pzmap(G, grid=True)
plt.show()
